# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

# %%
class LinkedList:
    def __init__(self):
        self.head=None
        
    def append(self,data):
        cur=self.head
        new_node=Node(data)
        if not self.head:
            self.head=new_node
            return
        while cur.next:
            cur=cur.next
        cur.next=new_node
    
    def display(self,head):
        x=[]
        cur=head
        while cur:
            x.append(cur.data)
            cur=cur.next
        print(x)
    
    def addTwoNumbers(self, l1, l2):
        '''
        dummy = cur = ListNode(0)
        carry = 0
        while l1 or l2 or carry:
            if l1:
                carry += l1.val
                l1 = l1.next
            if l2:
                carry += l2.val
                l2 = l2.next
            cur.next = ListNode(carry%10)
            cur = cur.next
            carry //= 10
        return dummy.next
        '''
        summ,carry=0,0
        res_head=res=Node(0)
        while l1 or l2 or carry:
            if l1 and l2:
                summ=l1.data+l2.data+carry
                l1=l1.next
                l2=l2.next
            elif l1:
                summ=l1.data+carry
                l1=l1.next
            elif l2:
                summ=l2.data+carry
                l2=l2.next            
            if summ>9:
                carry=1
            else:
                carry=0                
            res.next=Node(summ%10)
            res=res.next
        
        if carry:
            res.next=Node(carry)
            
        self.display(res_head.next)
        #return res_head.next

# %%
obj1=LinkedList()
obj1.append(7)
obj1.append(2)
obj1.append(3)
obj1.append(4)
obj2=LinkedList()
obj2.append(5)
obj2.append(6)
obj2.append(4)
obj2.addTwoNumbers(obj1.head,obj2.head)  #243+564=708
# Out:
# [2, 9, 7, 4]

# %%
        def display(head):
            x=[]
            cur=head
            while cur:
                x.append(cur.val)
                cur=cur.next
            print(x)
        
        def prepend_zeros(head,n):
            for _ in range(n):
                new_node=ListNode(0)
                new_node.next=head
                head=new_node
            return head        
        
        def length(head):
            cur=head
            c=0
            while cur:
                c+=1
                cur=cur.next
            return c
        
        def reverse(node):
            prev=None
            cur=next=node
            while cur:
                next=cur.next
                cur.next=prev
                prev=cur
                cur=next
            node=prev
            display(node)
            return node
        
        len1=length(l1)
        len2=length(l2)
        
        if len1<len2:
            l1=prepend_zeros(l1,len2-len1)
        else:
            l2=prepend_zeros(l2,len1-len2)
        
        display(l1)
        display(l2)
        res=res_head=ListNode(0)
        
        carry=0
        while l1 or l2 or carry:
            
            if l1:
                carry+=l1.val
                l1=l1.next
                
            if l2:
                carry+=l2.val
                l2=l2.next
                        
            res.next=ListNode(carry%10)
            res=res.next
            carry=carry//10

        return res_head.next
